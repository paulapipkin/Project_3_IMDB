# %% [markdown]
# ### Project 3 IMDB Part 4 - get more data
# - Paula Pipkin

# %%
import pandas as pd
import os, time,json
import matplotlib.pyplot as plt
import seaborn as sns

import tmdbsimple as tmdb 
from tqdm.notebook import tqdm_notebook

# %%
FOLDER = "big_data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2016.json',
#  'tmdb_api_results_2017.json',
#  'tmdb_api_results_2018.json',
#  'tmdb_api_results_2019.json']

# %%
def get_movies_cert(movie_id):
    # Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    # save the .info .releases dictionaries
    info = movie.info()
    releases = movie.releases()
    # Loop through countries in releases
    for c in releases['countries']:
        # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
            ## save a "certification" key in the info dict with the certification
           info['certification'] = c['certification']
    return info

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
with open('/Users/paula/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
tmdb.API_KEY =  login['api-key']

# %%
# Load in the dataframe from project part 1 as basics:
basics = pd.read_csv('data/title_basics.csv.gz')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  \
# 0                             Kate & Leopold        0       2001
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020
# 2                 The Other Side of the Wind        0       2018
# 3                          The Naked Monster        0       2005
# 4                       Crime and Punishment        0       2002
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
# I will use the last 10 completed years, so 2012 - 2021 
YEARS_TO_GET = [*range(2012, 2022, 1)]
errors = [ ]

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    # If it does not exist: create it
    if file_exists == False:
        # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)
    #Saving new year as the current df
    df = basics.loc[ basics['startYear']==YEAR].copy()
    # saving movie ids to list
    movie_ids = df['tconst'].copy()
    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)
    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
        #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movies_cert(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            errors.append([movie_id, e])
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)

print(f"- Total errors: {len(errors)}")
# Out:
# YEARS:   0%|          | 0/3 [00:00<?, ?it/s]
# Movies from 2019:   0%|          | 0/4721 [00:00<?, ?it/s]
# Movies from 2020:   0%|          | 0/4868 [00:00<?, ?it/s]
# Movies from 2021:   0%|          | 0/4841 [00:00<?, ?it/s]
# - Total errors: 3153

# %% [markdown]
# Concatenate dfs and organize data

# %%
#from https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe

from pathlib import Path

path =  'big_data/' 

# Get the files from the path provided in the OP
files = Path(path).glob('*.csv.gz')

# %%
dfs = list()
for f in files:
    data = pd.read_csv(f)
    # .stem is method for pathlib objects to get the filename w/o the extension
    data['file'] = f.stem
    dfs.append(data)

dfs
# Out:
# [        imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0249516    0.0  /t7zb6CnRQwhzQSq0apR4ESFYiWN.jpg
#  2     tt0285252    0.0  /pKOHinAVIkyqLliMaTHCSL1T4zU.jpg
#  3     tt0293069    0.0  /cj2isIuskSePAwpb2D6yUBZrhkJ.jpg
#  4     tt0337692    0.0  /5dUOTVeNPU2CmEfFniQ8TE6HChG.jpg
#  ...         ...    ...                               ...
#  3209  tt7547032    0.0                               NaN
#  3210  tt7867026    0.0  /4H3gxcDyFbyD3syAHcfGfu42zJ4.jpg
#  3211  tt8675644    0.0  /bkPwmPPVxSaT4lUztUOccHgWFi2.jpg
#  3212  tt8698020    0.0                               NaN
#  3213  tt9033128    0.0                               NaN
#
#                                    belongs_to_collection      budget  \
#  0                                                   NaN         NaN
#  1                                                   NaN  65000000.0
#  2                                                   NaN   4000000.0
#  3                                                   NaN         0.0
#  4                                                   NaN  25000000.0
#  ...                                                 ...         ...
#  3209                                                NaN         0.0
#  3210  {'id': 610471, 'name': 'Bloodbath at Pinky Hig...         0.0
#  3211                                                NaN         0.0
#  3212                                                NaN         0.0
#  3213                                                NaN         0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1     [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
#  2                        [{'id': 35, 'name': 'Comedy'}]
#  3                      [{'id': 53, 'name': 'Thriller'}]
#  4     [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
#  ...                                                 ...
#  3209                                                 []
#  3210  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#  3211                 [{'id': 10749, 'name': 'Romance'}]
#  3212  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#  3213                                                 []
#
#                                                 homepage        id  \
#  0                                                   NaN       NaN
#  1     http://www.thresholdanimationstudios.com/video...  116977.0
#  2                                                   NaN  112074.0
#  3                                                   NaN  136884.0
#  4            http://www.ontheroad-themovie.com/?lang=en   83770.0
#  ...                                                 ...       ...
#  3209                                                NaN  919499.0
#  3210                                                NaN  259678.0
#  3211                                                NaN  355037.0
#  3212                                                NaN  155776.0
#  3213                                                NaN  152428.0
#
#       original_language          original_title  ... runtime  \
#  0                  NaN                     NaN  ...     NaN
#  1                   en              Foodfight!  ...    87.0
#  2                   pl          Life's a Beach  ...   100.0
#  3                   en              Dark Blood  ...    86.0
#  4                   en             On the Road  ...   137.0
#  ...                ...                     ...  ...     ...
#  3209                zh                     我和你  ...     0.0
#  3210                ja                女子高生暴力教室  ...    70.0
#  3211                ko         전망 좋은 해변 - 두 여자  ...    70.0
#  3212                en       Heroes and Demons  ...    93.0
#  3213                de  Dostavit' ljuboj cenoj  ...     0.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  ...                                                 ...       ...
#  3209                                                 []  Released
#  3210  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#  3211  [{'english_name': 'Korean', 'iso_639_1': 'ko',...  Released
#  3212  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3213  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
#
#                                    tagline                            title  \
#  0                                     NaN                              NaN
#  1                                     NaN                       Foodfight!
#  2                                     NaN                   Life's a Beach
#  3                                     NaN                       Dark Blood
#  4         The best teacher is experience.                      On the Road
#  ...                                   ...                              ...
#  3209                                  NaN                              我和你
#  3210                                  NaN   Bloodbath at Pinky High Part 1
#  3211                                  NaN  A Beach With A View - Two Women
#  3212  Our last hope, our greatest threat.                Heroes and Demons
#  3213                                  NaN           Dostavit' ljuboj cenoj
#
#       video  vote_average  vote_count certification                      file
#  0      NaN           NaN         NaN           NaN  final_tmdb_data_2012.csv
#  1      0.0         1.856       108.0         PG-13  final_tmdb_data_2012.csv
#  2      0.0         2.500         5.0             R  final_tmdb_data_2012.csv
#  3      0.0         6.100        17.0           NaN  final_tmdb_data_2012.csv
#  4      0.0         5.604       734.0             R  final_tmdb_data_2012.csv
#  ...    ...           ...         ...           ...                       ...
#  3209   0.0         0.000         0.0           NaN  final_tmdb_data_2012.csv
#  3210   0.0         4.500         4.0           NaN  final_tmdb_data_2012.csv
#  3211   0.0         0.000         0.0           NaN  final_tmdb_data_2012.csv
#  3212   0.0         7.200        12.0           NaN  final_tmdb_data_2012.csv
#  3213   0.0         5.000         1.0           NaN  final_tmdb_data_2012.csv
#
#  [3214 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0255820    0.0                               NaN
#  2     tt0359950    0.0  /v52aVrsuWPxbRXC1wb5plWDJ9UW.jpg
#  3     tt0409379    0.0  /56NwJuplsUl9WIZfF0h1QH0wsJ1.jpg
#  4     tt0452183    0.0                               NaN
#  ...         ...    ...                               ...
#  3448  tt8159944    0.0                               NaN
#  3449  tt8653804    0.0                               NaN
#  3450  tt8728782    0.0                               NaN
#  3451  tt9278070    0.0  /fSecWWA6IPcfXNgv7Xi6sP2VRQr.jpg
#  3452  tt9546080    0.0                               NaN
#
#       belongs_to_collection      budget  \
#  0                      NaN         NaN
#  1                      NaN   2000000.0
#  2                      NaN  90000000.0
#  3                      NaN         0.0
#  4                      NaN         0.0
#  ...                    ...         ...
#  3448                   NaN         0.0
#  3449                   NaN         0.0
#  3450                   NaN         0.0
#  3451                   NaN         0.0
#  3452                   NaN         0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#  2     [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
#  3     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
#  4                        [{'id': 35, 'name': 'Comedy'}]
#  ...                                                 ...
#  3448                                                 []
#  3449                     [{'id': 27, 'name': 'Horror'}]
#  3450                                                 []
#  3451                [{'id': 99, 'name': 'Documentary'}]
#  3452  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                                 homepage        id  \
#  0                                                   NaN       NaN
#  1                                                   NaN  323498.0
#  2     https://www.20thcenturystudios.com/movies/the-...  116745.0
#  3                             http://insecretmovie.com/  172226.0
#  4                                                   NaN  439174.0
#  ...                                                 ...       ...
#  3448                                                NaN  713422.0
#  3449                                                NaN  985060.0
#  3450                                                NaN  613829.0
#  3451                                                NaN  312177.0
#  3452                                                NaN  263539.0
#
#       original_language                          original_title  ... runtime  \
#  0                  NaN                                     NaN  ...     NaN
#  1                   en                       Return to Babylon  ...    75.0
#  2                   en         The Secret Life of Walter Mitty  ...   114.0
#  3                   en                               In Secret  ...   101.0
#  4                   en                             Blunt Movie  ...    83.0
#  ...                ...                                     ...  ...     ...
#  3448                en         Paranormal Investigation Agency  ...    69.0
#  3449                en                                Tumors 2  ...    70.0
#  3450                fr                 Le miroir et l'échafaud  ...    71.0
#  3451                en  The Nativity: The Life of Jesus Christ  ...    92.0
#  3452                en                              Crazy Love  ...    90.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1                                                    []  Released
#  2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  ...                                                 ...       ...
#  3448                                                 []  Released
#  3449                                                 []  Released
#  3450                                                 []  Released
#  3451  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3452  [{'english_name': 'Indonesian', 'iso_639_1': '...  Released
#
#                                                  tagline  \
#  0                                                   NaN
#  1                                                   NaN
#  2                           Stop Dreaming, Start Living
#  3                                                   NaN
#  4     From the creators of ABSOLUTELY NOTHING before...
#  ...                                                 ...
#  3448                                                NaN
#  3449                                                NaN
#  3450                                                NaN
#  3451                                                NaN
#  3452      Drama, Romance, First Love, High School Lover
#
#                                         title video  vote_average  vote_count  \
#  0                                        NaN   NaN           NaN         NaN
#  1                          Return to Babylon   0.0         6.000        22.0
#  2            The Secret Life of Walter Mitty   0.0         7.155      6664.0
#  3                                  In Secret   0.0         6.232       170.0
#  4                                Blunt Movie   0.0         3.700         3.0
#  ...                                      ...   ...           ...         ...
#  3448         Paranormal Investigation Agency   0.0         0.000         0.0
#  3449                                Tumors 2   0.0         0.000         0.0
#  3450             The Mirror and the Scaffold   0.0         0.000         0.0
#  3451  The Nativity: The Life of Jesus Christ   0.0         0.000         0.0
#  3452                              Crazy Love   0.0         6.000         1.0
#
#       certification                      file
#  0              NaN  final_tmdb_data_2013.csv
#  1              NaN  final_tmdb_data_2013.csv
#  2               PG  final_tmdb_data_2013.csv
#  3                R  final_tmdb_data_2013.csv
#  4                R  final_tmdb_data_2013.csv
#  ...            ...                       ...
#  3448           NaN  final_tmdb_data_2013.csv
#  3449           NaN  final_tmdb_data_2013.csv
#  3450           NaN  final_tmdb_data_2013.csv
#  3451            PG  final_tmdb_data_2013.csv
#  3452           NaN  final_tmdb_data_2013.csv
#
#  [3453 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0329539    0.0                               NaN
#  2     tt0365907    0.0  /isrro0soStk2tSWMsI50lPPhUsU.jpg
#  3     tt0403935    0.0  /romORaZvZqMRjTPgw0HrAZpVn9V.jpg
#  4     tt0424859    0.0                               NaN
#  ...         ...    ...                               ...
#  3649  tt8942834    0.0  /wO9o7sdDuufc4fE2pL83aeMgpdT.jpg
#  3650  tt9085782    0.0                               NaN
#  3651  tt9208638    0.0                               NaN
#  3652  tt9287460    0.0                               NaN
#  3653  tt9387330    0.0  /e62gV9Y4JkJyjedAw9UVBZBbSH5.jpg
#
#       belongs_to_collection      budget  \
#  0                      NaN         NaN
#  1                      NaN         0.0
#  2                      NaN  28000000.0
#  3                      NaN         0.0
#  4                      NaN         0.0
#  ...                    ...         ...
#  3649                   NaN         0.0
#  3650                   NaN         0.0
#  3651                   NaN       500.0
#  3652                   NaN         0.0
#  3653                   NaN         0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1                        [{'id': 35, 'name': 'Comedy'}]
#  2     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#  3     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#  4                                                    []
#  ...                                                 ...
#  3649                   [{'id': 10402, 'name': 'Music'}]
#  3650  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#  3651                     [{'id': 27, 'name': 'Horror'}]
#  3652  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...
#  3653  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                                 homepage        id  \
#  0                                                   NaN       NaN
#  1                                                   NaN  274341.0
#  2                                                   NaN  169917.0
#  3                                                   NaN  308165.0
#  4                                                   NaN  285294.0
#  ...                                                 ...       ...
#  3649                                                NaN  345474.0
#  3650                                                NaN  668763.0
#  3651  https://midnightreleasing.com/filmcatalog/carn...  782140.0
#  3652                                                NaN  415457.0
#  3653                                                NaN  465566.0
#
#       original_language               original_title  ... runtime  \
#  0                  NaN                          NaN  ...     NaN
#  1                   en                    Rice Girl  ...    95.0
#  2                   en  A Walk Among the Tombstones  ...   114.0
#  3                   hi                  एक्शन जैकसन  ...   144.0
#  4                   en              The Ninth Cloud  ...    93.0
#  ...                ...                          ...  ...     ...
#  3649                en     Above & Beyond: Acoustic  ...    82.0
#  3650                kn                        Power  ...   173.0
#  3651                en          Carnivale Creepshow  ...    74.0
#  3652                en          Max Saves the World  ...    88.0
#  3653                zh                      你是男的我也爱  ...    98.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#  4                                                    []  Released
#  ...                                                 ...       ...
#  3649  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3650  [{'english_name': 'Kannada', 'iso_639_1': 'kn'...  Released
#  3651  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3652  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3653  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...  Released
#
#                                                  tagline  \
#  0                                                   NaN
#  1     «For Windy Yee, a big break in Hollywood can m...
#  2        Some people are afraid of all the wrong things
#  3     Naa Commitment, Naa Appointment, Only Punishment!
#  4                         Even Reality can't stop Zena.
#  ...                                                 ...
#  3649                                                NaN
#  3650                                                NaN
#  3651        Come on in...to where the nightmares begin!
#  3652                                                NaN
#  3653                                                NaN
#
#                              title video  vote_average  vote_count  \
#  0                             NaN   NaN           NaN         NaN
#  1                       Rice Girl   0.0         1.000         2.0
#  2     A Walk Among the Tombstones   0.0         6.300      2448.0
#  3                  Action Jackson   0.0         4.333        24.0
#  4                 The Ninth Cloud   0.0         4.000         1.0
#  ...                           ...   ...           ...         ...
#  3649     Above & Beyond: Acoustic   1.0        10.000         1.0
#  3650                        Power   0.0         5.000         2.0
#  3651          Carnivale Creepshow   0.0         2.000         1.0
#  3652          Max Saves the World   0.0         0.000         0.0
#  3653                    Like Love   0.0         7.000         1.0
#
#       certification                      file
#  0              NaN  final_tmdb_data_2014.csv
#  1              NaN  final_tmdb_data_2014.csv
#  2                R  final_tmdb_data_2014.csv
#  3              NaN  final_tmdb_data_2014.csv
#  4              NaN  final_tmdb_data_2014.csv
#  ...            ...                       ...
#  3649           NaN  final_tmdb_data_2014.csv
#  3650           NaN  final_tmdb_data_2014.csv
#  3651           NaN  final_tmdb_data_2014.csv
#  3652           NaN  final_tmdb_data_2014.csv
#  3653           NaN  final_tmdb_data_2014.csv
#
#  [3654 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0191476    0.0                               NaN
#  2     tt0369610    0.0  /dF6FjTZzRTENfB4R17HDN20jLT2.jpg
#  3     tt0420293    0.0  /b0p0OPx1ZDZVc8iDB1kle0Cc2H9.jpg
#  4     tt0462335    0.0  /wESuRMxELPAwo56qFRcoyI4p20F.jpg
#  ...         ...    ...                               ...
#  3713  tt9146210    0.0                               NaN
#  3714  tt9164964    0.0                               NaN
#  3715  tt9204890    0.0                               NaN
#  3716  tt9440450    0.0                               NaN
#  3717  tt9860252    0.0                               NaN
#
#                                    belongs_to_collection       budget  \
#  0                                                   NaN          NaN
#  1                                                   NaN          0.0
#  2     {'id': 328, 'name': 'Jurassic Park Collection'...  150000000.0
#  3                                                   NaN          0.0
#  4                                                   NaN          0.0
#  ...                                                 ...          ...
#  3713                                                NaN          0.0
#  3714                                                NaN          0.0
#  3715                                                NaN          0.0
#  3716                                                NaN          0.0
#  3717                                                NaN          0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1                        [{'id': 35, 'name': 'Comedy'}]
#  2     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#  3                      [{'id': 53, 'name': 'Thriller'}]
#  4                         [{'id': 18, 'name': 'Drama'}]
#  ...                                                 ...
#  3713                      [{'id': 18, 'name': 'Drama'}]
#  3714                                                 []
#  3715                      [{'id': 18, 'name': 'Drama'}]
#  3716  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#  3717                                                 []
#
#                                            homepage        id  \
#  0                                              NaN       NaN
#  1                                              NaN  365165.0
#  2                    http://www.jurassicworld.com/  135397.0
#  3     http://www.stanfordprisonexperimentfilm.com/  308032.0
#  4                      http://www.highrisefilm.com  254302.0
#  ...                                            ...       ...
#  3713                                           NaN  349683.0
#  3714                                           NaN  660095.0
#  3715                                           NaN  869161.0
#  3716                                           NaN  474174.0
#  3717                                           NaN  607664.0
#
#       original_language                  original_title  ... runtime  \
#  0                  NaN                             NaN  ...     NaN
#  1                   ro                Această lehamite  ...    98.0
#  2                   en                  Jurassic World  ...   124.0
#  3                   en  The Stanford Prison Experiment  ...   122.0
#  4                   en                       High-Rise  ...   119.0
#  ...                ...                             ...  ...     ...
#  3713                uk             Captum (лат. Полон)  ...    84.0
#  3714                en                         Sikisma  ...     0.0
#  3715                en              Red Big Fire Truck  ...    81.0
#  3716                en                     Out of Luck  ...   106.0
#  3717                en             As Long As It Takes  ...    80.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1     [{'english_name': 'Romanian', 'iso_639_1': 'ro...  Released
#  2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  4     [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
#  ...                                                 ...       ...
#  3713  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
#  3714                                                 []  Released
#  3715  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3716                                                 []  Released
#  3717                                                 []  Released
#
#                                           tagline  \
#  0                                            NaN
#  1                                            NaN
#  2                              The park is open.
#  3     They were given 2 weeks. It lasted 6 days.
#  4                    Leave the real world behind
#  ...                                          ...
#  3713                                         NaN
#  3714                                         NaN
#  3715                                         NaN
#  3716                                         NaN
#  3717                                         NaN
#
#                                 title video  vote_average  vote_count  \
#  0                                NaN   NaN           NaN         NaN
#  1                             Fed Up   0.0         4.400         5.0
#  2                     Jurassic World   0.0         6.676     18472.0
#  3     The Stanford Prison Experiment   0.0         6.876       817.0
#  4                          High-Rise   0.0         5.651       988.0
#  ...                              ...   ...           ...         ...
#  3713         CAPTUM (Lat. Captivity)   0.0         5.000         1.0
#  3714                         Sikisma   0.0         0.000         0.0
#  3715              Red Big Fire Truck   0.0         0.000         0.0
#  3716                     Out of Luck   0.0         2.000         2.0
#  3717             As Long As It Takes   0.0         0.000         0.0
#
#       certification                      file
#  0              NaN  final_tmdb_data_2015.csv
#  1              NaN  final_tmdb_data_2015.csv
#  2            PG-13  final_tmdb_data_2015.csv
#  3                R  final_tmdb_data_2015.csv
#  4                R  final_tmdb_data_2015.csv
#  ...            ...                       ...
#  3713           NaN  final_tmdb_data_2015.csv
#  3714           NaN  final_tmdb_data_2015.csv
#  3715           NaN  final_tmdb_data_2015.csv
#  3716           NaN  final_tmdb_data_2015.csv
#  3717           NaN  final_tmdb_data_2015.csv
#
#  [3718 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0315642    0.0  /lD6lYulY6js9EAgUufh2ekNnCR4.jpg
#  2     tt0376479    0.0  /fDxdfM4Qj2Qhc6EZYPyB3k4xatw.jpg
#  3     tt0443533    0.0  /iU9ij6jSQOJDPFnqBUPzEY2eOs6.jpg
#  4     tt0470936    0.0                               NaN
#  ...         ...    ...                               ...
#  3954  tt9387300    0.0  /bASfXeZbPcizNUGFWbPpzeMHgq9.jpg
#  3955  tt9434008    0.0                               NaN
#  3956  tt9547878    0.0                               NaN
#  3957  tt9741588    0.0  /f2HAgJuweEdeQJi4Mzshu6WxRPD.jpg
#  3958  tt9753312    0.0  /ifhAWtypQ7RBNYKxU674WTdSaio.jpg
#
#       belongs_to_collection      budget  \
#  0                      NaN         NaN
#  1                      NaN   5200000.0
#  2                      NaN         0.0
#  3                      NaN  20000000.0
#  4                      NaN         0.0
#  ...                    ...         ...
#  3954                   NaN         0.0
#  3955                   NaN         0.0
#  3956                   NaN         0.0
#  3957                   NaN         0.0
#  3958                   NaN         0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1     [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#  2     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#  3     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#  4                                                    []
#  ...                                                 ...
#  3954  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#  3955  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
#  3956  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#  3957  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#  3958                                                 []
#
#                                  homepage        id original_language  \
#  0                                    NaN       NaN               NaN
#  1                                    NaN  275269.0                hi
#  2     http://www.americanpastoral.movie/  326285.0                en
#  3                                    NaN  410366.0                en
#  4                                    NaN  532608.0                hy
#  ...                                  ...       ...               ...
#  3954                                 NaN  594885.0                zh
#  3955                                 NaN  398655.0                zh
#  3956                                 NaN  914301.0                zh
#  3957                                 NaN  475943.0                en
#  3958                                 NaN  417568.0                pt
#
#                             original_title  ... runtime  \
#  0                                     NaN  ...     NaN
#  1                                   वज़ीर  ...   103.0
#  2                       American Pastoral  ...   108.0
#  3                     The History of Love  ...   134.0
#  4                  Tak erkir, tsurt dzmer  ...   104.0
#  ...                                   ...  ...     ...
#  3954                            错了性别, 不错爱  ...    60.0
#  3955                       Strange Battle  ...    90.0
#  3956                                Hi高考君  ...     0.0
#  3957                       Couple of Days  ...   103.0
#  3958  O que seria deste mundo sem paixão?  ...    72.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#  2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3     [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
#  4     [{'english_name': 'Armenian', 'iso_639_1': 'hy...  Released
#  ...                                                 ...       ...
#  3954  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...  Released
#  3955  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...  Released
#  3956  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...  Released
#  3957  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3958                                                 []  Released
#
#                                  tagline                                title  \
#  0                                   NaN                                  NaN
#  1     This new year make your best move                                Wazir
#  2           A radically ordinary story.                    American Pastoral
#  3                                   NaN                  The History of Love
#  4                                   NaN             Hot Country, Cold Winter
#  ...                                 ...                                  ...
#  3954                                NaN                           Girls Love
#  3955                                NaN                       Strange Battle
#  3956                                NaN                                Hi高考君
#  3957                                NaN                       Couple of Days
#  3958                                NaN  What of This World Without Passion?
#
#       video  vote_average  vote_count certification                      file
#  0      NaN           NaN         NaN           NaN  final_tmdb_data_2016.csv
#  1      0.0         6.600       101.0         PG-13  final_tmdb_data_2016.csv
#  2      0.0         6.129       591.0             R  final_tmdb_data_2016.csv
#  3      0.0         6.429        78.0           NaN  final_tmdb_data_2016.csv
#  4      0.0         0.000         0.0           NaN  final_tmdb_data_2016.csv
#  ...    ...           ...         ...           ...                       ...
#  3954   0.0         5.000         4.0           NaN  final_tmdb_data_2016.csv
#  3955   0.0         0.000         0.0           NaN  final_tmdb_data_2016.csv
#  3956   0.0         0.000         0.0           NaN  final_tmdb_data_2016.csv
#  3957   0.0         4.000         1.0           NaN  final_tmdb_data_2016.csv
#  3958   0.0         5.000         1.0           NaN  final_tmdb_data_2016.csv
#
#  [3959 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0100275    0.0  /2S2XTeS2b0LPnqzXBDD3ZmwPF2X.jpg
#  2     tt0137204    0.0  /92PDk4xvjTdGXrQYF0QOojK2btM.jpg
#  3     tt0331314    0.0   /BiDHVlIs5Pm2uSqd2e2n7yT582.jpg
#  4     tt0339736    0.0  /lobIr3Fq2buOUxXtursuEJEjfri.jpg
#  ...         ...    ...                               ...
#  4317  tt9675050    0.0                               NaN
#  4318  tt9704488    0.0                               NaN
#  4319  tt9719078    0.0                               NaN
#  4320  tt9792896    0.0                               NaN
#  4321  tt9837530    0.0  /l9tag57iGKF8dKtFbAi9KUFu87t.jpg
#
#       belongs_to_collection     budget  \
#  0                      NaN        NaN
#  1                      NaN        0.0
#  2                      NaN        0.0
#  3                      NaN        0.0
#  4                      NaN  4000000.0
#  ...                    ...        ...
#  4317                   NaN        0.0
#  4318                   NaN        0.0
#  4319                   NaN        0.0
#  4320                   NaN        0.0
#  4321                   NaN        0.0
#
#                                                   genres homepage        id  \
#  0                                                   NaN      NaN       NaN
#  1     [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...      NaN  467254.0
#  2     [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...      NaN  503326.0
#  3     [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...      NaN  435995.0
#  4                        [{'id': 27, 'name': 'Horror'}]      NaN  444193.0
#  ...                                                 ...      ...       ...
#  4317                                                 []      NaN  512559.0
#  4318                                                 []      NaN  530236.0
#  4319                                                 []      NaN  664734.0
#  4320                                                 []      NaN  959719.0
#  4321  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...      NaN  502234.0
#
#       original_language          original_title  ... runtime  \
#  0                  NaN                     NaN  ...     NaN
#  1                   es   La telenovela errante  ...    80.0
#  2                   en         Joe Finds Grace  ...    83.0
#  3                   en         Bunyan and Babe  ...    84.0
#  4                   en         The Evil Within  ...    98.0
#  ...                ...                     ...  ...     ...
#  4317                en                  Litost  ...    57.0
#  4318                zh         Through the Eye  ...    95.0
#  4319                en  Qing Tian Xiang Yao Lu  ...    87.0
#  4320                ko           신의 숲 - 운명의 시작  ...     0.0
#  4321                zh                 小金刚纽约大冒  ...     0.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1     [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
#  2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  ...                                                 ...       ...
#  4317                                                 []  Released
#  4318                                                 []  Released
#  4319                                                 []  Released
#  4320                                                 []  Released
#  4321  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                  tagline  \
#  0                                                   NaN
#  1                                                   NaN
#  2                                         A GLOVE STORY
#  3             You don't have to BE BIG to do BIG THINGS
#  4                        You Can't Run From a Nightmare
#  ...                                                 ...
#  4317  A State of Agony and Torment Created by the Su...
#  4318                                                NaN
#  4319                                                NaN
#  4320                                                NaN
#  4321                                                NaN
#
#                           title video  vote_average  vote_count certification  \
#  0                          NaN   NaN           NaN         NaN           NaN
#  1     The Wandering Soap Opera   0.0         6.625        12.0           NaN
#  2              Joe Finds Grace   0.0        10.000         1.0           NaN
#  3              Bunyan and Babe   0.0         6.000        18.0            PG
#  4              The Evil Within   0.0         5.851        77.0           NaN
#  ...                        ...   ...           ...         ...           ...
#  4317                    Litost   0.0         0.000         0.0           NaN
#  4318           Through the Eye   0.0         0.000         0.0           NaN
#  4319      Monster Hunt Bao Man   0.0         2.500         1.0           NaN
#  4320                     Taiga   0.0         0.000         0.0           NaN
#  4321      Monkey King Reloaded   0.0         6.000         2.0            PG
#
#                            file
#  0     final_tmdb_data_2017.csv
#  1     final_tmdb_data_2017.csv
#  2     final_tmdb_data_2017.csv
#  3     final_tmdb_data_2017.csv
#  4     final_tmdb_data_2017.csv
#  ...                        ...
#  4317  final_tmdb_data_2017.csv
#  4318  final_tmdb_data_2017.csv
#  4319  final_tmdb_data_2017.csv
#  4320  final_tmdb_data_2017.csv
#  4321  final_tmdb_data_2017.csv
#
#  [4322 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0069049    0.0  /zjG95oDnBcFKMPgBEmmuNVOMC90.jpg
#  2     tt0192528    0.0  /gkBxjhtVEqgxOiRwRfWw1j7ez6K.jpg
#  3     tt0360556    0.0  /7oy4miyq4WYYy0xtX6lbNVPrEsr.jpg
#  4     tt0365545    0.0  /ljTYcQ3pkzYF52Z8ev1Z1UThnPy.jpg
#  ...         ...    ...                               ...
#  4544  tt9889934    0.0                               NaN
#  4545  tt9899840    0.0                               NaN
#  4546  tt9899880    0.0  /rmy3Um1ZVf0CiVUeS3kXURsQcU2.jpg
#  4547  tt9904530    0.0                               NaN
#  4548  tt9905072    0.0  /grhhsZmfS2Uw8SWFhwIHKhfc2Jp.jpg
#
#       belongs_to_collection      budget  \
#  0                      NaN         NaN
#  1                      NaN  12000000.0
#  2                      NaN   5000000.0
#  3                      NaN         0.0
#  4                      NaN         0.0
#  ...                    ...         ...
#  4544                   NaN         0.0
#  4545                   NaN         0.0
#  4546                   NaN         0.0
#  4547                   NaN         0.0
#  4548                   NaN         0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1                         [{'id': 18, 'name': 'Drama'}]
#  2                         [{'id': 18, 'name': 'Drama'}]
#  3     [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
#  4     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#  ...                                                 ...
#  4544                                                 []
#  4545                  [{'id': 10751, 'name': 'Family'}]
#  4546  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#  4547  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#  4548                      [{'id': 18, 'name': 'Drama'}]
#
#                                         homepage        id original_language  \
#  0                                           NaN       NaN               NaN
#  1        https://www.netflix.com/title/80085566  299782.0                en
#  2                                           NaN  567662.0                en
#  3     https://www.hbo.com/movies/fahrenheit-451  401905.0                en
#  4        https://www.netflix.com/title/80189630  519035.0                en
#  ...                                         ...       ...               ...
#  4544                                        NaN  609706.0                kk
#  4545                                        NaN  610089.0                fa
#  4546                                        NaN  620124.0                fa
#  4547                                        NaN  904140.0                fr
#  4548                                        NaN  517966.0                fr
#
#                    original_title  ... runtime  \
#  0                            NaN  ...     NaN
#  1     The Other Side of the Wind  ...   122.0
#  2                 Reverse Heaven  ...   104.0
#  3                 Fahrenheit 451  ...   100.0
#  4             Nappily Ever After  ...   100.0
#  ...                          ...  ...     ...
#  4544   Шыракшы (Хранитель света)  ...    95.0
#  4545           Khaleh Ghurbagheh  ...    81.0
#  4546                      کلمبوس  ...    82.0
#  4547              Scream Returns  ...    48.0
#  4548                     Yolanda  ...    58.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  ...                                                 ...       ...
#  4544  [{'english_name': 'Kazakh', 'iso_639_1': 'kk',...  Released
#  4545  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#  4546  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#  4547  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
#  4548  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
#
#                                                  tagline  \
#  0                                                   NaN
#  1                                40 years in the making
#  2     Heaven's in trouble and there's one man who ca...
#  3                        Knowledge is a dangerous thing
#  4                                     Let yourself grow
#  ...                                                 ...
#  4544                                                NaN
#  4545                                                NaN
#  4546                                                NaN
#  4547                                                NaN
#  4548                                                NaN
#
#                                   title video  vote_average  vote_count  \
#  0                                  NaN   NaN           NaN         NaN
#  1           The Other Side of the Wind   0.0         6.683       161.0
#  2                        Heaven & Hell   0.0         6.300         6.0
#  3                       Fahrenheit 451   0.0         5.421       711.0
#  4                   Nappily Ever After   0.0         7.200       765.0
#  ...                                ...   ...           ...         ...
#  4544  Shyrakshy: Guardian of the Light   0.0         0.000         0.0
#  4545                       Auntie Frog   0.0         0.000         0.0
#  4546                          Columbus   0.0         6.000         1.0
#  4547                    Scream Returns   0.0         6.000         2.0
#  4548                           Yolanda   0.0         0.000         0.0
#
#       certification                      file
#  0              NaN  final_tmdb_data_2018.csv
#  1                R  final_tmdb_data_2018.csv
#  2              NaN  final_tmdb_data_2018.csv
#  3            PG-13  final_tmdb_data_2018.csv
#  4              NaN  final_tmdb_data_2018.csv
#  ...            ...                       ...
#  4544           NaN  final_tmdb_data_2018.csv
#  4545           NaN  final_tmdb_data_2018.csv
#  4546           NaN  final_tmdb_data_2018.csv
#  4547           NaN  final_tmdb_data_2018.csv
#  4548           NaN  final_tmdb_data_2018.csv
#
#  [4549 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0385887    0.0  /xMHeU84wLQ9uH9acJ0oPgdii9wO.jpg
#  2     tt0437086    0.0  /8RKBHHRqOMOLh5qW3sS6TSFTd8h.jpg
#  3     tt0441881    0.0  /7uacpbrJd9g9xSTLgfyg1NwkAiu.jpg
#  4     tt0448115    0.0  /qwgGtdlLMKYvT2tV8hLY22syRHN.jpg
#  ...         ...    ...                               ...
#  4746  tt9906644    0.0  /htoReVItKtolso5VJqFqJDBaOwm.jpg
#  4747  tt9913660    0.0   /z6YpkQiWLnRKl5yQD9dSiPDFWN.jpg
#  4748  tt9913936    0.0  /i4moNlJn4EpSE5auFeoeIae366g.jpg
#  4749  tt9914942    0.0  /tjHUeULyw2vtS1DXFp0OHfhUzRX.jpg
#  4750  tt9915872    0.0                               NaN
#
#                                    belongs_to_collection       budget  \
#  0                                                   NaN          NaN
#  1                                                   NaN   26000000.0
#  2                                                   NaN  170000000.0
#  3                                                   NaN   23934823.0
#  4     {'id': 724848, 'name': 'Shazam! Collection', '...   80000000.0
#  ...                                                 ...          ...
#  4746                                                NaN          0.0
#  4747                                                NaN          0.0
#  4748                                                NaN          0.0
#  4749                                                NaN          0.0
#  4750                                                NaN          0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# ...
#  4748  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
#  4749  [{'english_name': 'Catalan', 'iso_639_1': 'ca'...  Released
#  4750                                                 []  Released
#
#                                             tagline  \
#  0                                              NaN
#  1                                              NaN
#  2                 An angel falls. A warrior rises.
#  3     Outnumbered. Outgunned. Never out of courage
#  4                               Just say the word.
#  ...                                            ...
#  4746                                           NaN
#  4747                                           NaN
#  4748                                           NaN
#  4749                                           NaN
#  4750                                           NaN
#
#                                       title video  vote_average  vote_count  \
#  0                                      NaN   NaN           NaN         NaN
#  1                      Motherless Brooklyn   0.0         6.709      1196.0
#  2                      Alita: Battle Angel   0.0         7.198      7728.0
#  3     Danger Close: The Battle of Long Tan   0.0         6.929       241.0
#  4                                  Shazam!   0.0         7.049      7895.0
#  ...                                    ...   ...           ...         ...
#  4746                             Manoharam   0.0         6.200        10.0
#  4747                            No Apology   0.0         8.000         1.0
#  4748                              Paradise   0.0         8.500         2.0
#  4749                Life without Sara Amat   0.0         7.714         7.0
#  4750                  The Last White Witch   0.0         0.000         0.0
#
#       certification                      file
#  0              NaN  final_tmdb_data_2019.csv
#  1                R  final_tmdb_data_2019.csv
#  2            PG-13  final_tmdb_data_2019.csv
#  3                R  final_tmdb_data_2019.csv
#  4            PG-13  final_tmdb_data_2019.csv
#  ...            ...                       ...
#  4746           NaN  final_tmdb_data_2019.csv
#  4747           NaN  final_tmdb_data_2019.csv
#  4748           NaN  final_tmdb_data_2019.csv
#  4749           NaN  final_tmdb_data_2019.csv
#  4750           NaN  final_tmdb_data_2019.csv
#
#  [4751 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0062336    0.0  /fw5tsNib4QZBEw18xmebpVe3WZ8.jpg
#  2     tt0805647    0.0  /8rIoyM6zYXJNjzGseT3MRusMPWl.jpg
#  3     tt0920462    0.0  /mwXmcrvjOJwzsJSuNEupjisXUt6.jpg
#  4     tt0926132    0.0  /op14w44FvLUqH7TWyT1ijzrSfXV.jpg
#  ...         ...    ...                               ...
#  3821  tt9904004    0.0                               NaN
#  3822  tt9904802    0.0  /tVa0v0iX7ksdfHtYdTdJglZWy5N.jpg
#  3823  tt9911196    0.0  /f1WhKsQZEPjOHQ4wTmlq75z0RF6.jpg
#  3824  tt9916190    0.0  /d98qmYGL6S7ku7txjBvE8Zy0SMQ.jpg
#  3825  tt9916362    0.0  /imgc14olSDlAlf1z3nC11cL8Zyn.jpg
#
#       belongs_to_collection  budget  \
#  0                      NaN     NaN
#  1                      NaN     0.0
#  2                      NaN     0.0
#  3                      NaN     0.0
#  4                      NaN     0.0
#  ...                    ...     ...
#  3821                   NaN     0.0
#  3822                   NaN     0.0
#  3823                   NaN     0.0
#  3824                   NaN     0.0
#  3825                   NaN     0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1     [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
#  2     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#  3                         [{'id': 18, 'name': 'Drama'}]
#  4                        [{'id': 27, 'name': 'Horror'}]
#  ...                                                 ...
#  3821                                                 []
#  3822                     [{'id': 10752, 'name': 'War'}]
#  3823  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#  3824  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#  3825  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
#
#                                                 homepage        id  \
#  0                                                   NaN       NaN
#  1             http://poetastros.com/el-tango-del-viudo/  602986.0
#  2                      https://www.thewitchesmovie.net/  531219.0
#  3                  https://www.lostgirlslovehotels.film  479259.0
#  4                              http://www.roadtored.com  651448.0
#  ...                                                 ...       ...
#  3821                                                NaN  678495.0
#  3822     https://gooddeedentertainment.com/enemy-lines/  679796.0
#  3823                                                NaN  591915.0
#  3824                                                NaN  633490.0
#  3825  http://www.avalon.me/production/feature-films/...  655187.0
#
#       original_language                             original_title  ...  \
#  0                  NaN                                        NaN  ...
#  1                   es  El tango del viudo y su espejo deformante  ...
#  2                   en                   Roald Dahl's The Witches  ...
#  3                   en                   Lost Girls & Love Hotels  ...
#  4                   en                                  Darkslide  ...
#  ...                ...                                        ...  ...
#  3821                en                             Your Iron Lady  ...
#  3822                en                                Enemy Lines  ...
#  3823                nl             De Beentjes van Sint-Hildegard  ...
#  3824                en                                  Safeguard  ...
#  3825                eu                                   Akelarre  ...
#
#       runtime                                   spoken_languages    status  \
#  0        NaN                                                NaN       NaN
#  1       63.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
#  2      106.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3       97.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  4      121.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  ...      ...                                                ...       ...
#  3821    92.0                                                 []  Released
#  3822    92.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3823   103.0  [{'english_name': 'Dutch', 'iso_639_1': 'nl', ...  Released
#  3824    94.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3825    92.0  [{'english_name': 'Basque', 'iso_639_1': 'eu',...  Released
#
#                                        tagline  \
#  0                                         NaN
#  1                                         NaN
#  2                               They're real!
#  3                                         NaN
#  4                          Keep Moving or Die
#  ...                                       ...
#  3821                                      NaN
#  3822                   Courage has no border.
#  3823                                      NaN
#  3824  Protecting your family comes at a cost.
#  3825                                      NaN
#
#                                                    title video  vote_average  \
#  0                                                   NaN   NaN           NaN
#  1     The Tango of the Widower and Its Distorting Mi...   0.0         5.300
#  2                              Roald Dahl's The Witches   0.0         6.433
#  3                              Lost Girls & Love Hotels   0.0         5.260
#  4                                             Darkslide   0.0         6.500
#  ...                                                 ...   ...           ...
#  3821                                     Your Iron Lady   0.0         3.700
#  3822                                        Enemy Lines   0.0         5.393
#  3823                                The Marriage Escape   0.0         7.963
#  3824                                          Safeguard   0.0         6.500
#  3825                                              Coven   0.0         6.755
#
#        vote_count certification                      file
#  0            NaN           NaN  final_tmdb_data_2020.csv
#  1            3.0           NaN  final_tmdb_data_2020.csv
#  2         2325.0            PG  final_tmdb_data_2020.csv
#  3          123.0             R  final_tmdb_data_2020.csv
#  4            2.0           NaN  final_tmdb_data_2020.csv
#  ...          ...           ...                       ...
#  3821         3.0           NaN  final_tmdb_data_2020.csv
#  3822        28.0           NaN  final_tmdb_data_2020.csv
#  3823        27.0           NaN  final_tmdb_data_2020.csv
#  3824         2.0           NaN  final_tmdb_data_2020.csv
#  3825       235.0            NR  final_tmdb_data_2020.csv
#
#  [3826 rows x 27 columns],
#          imdb_id  adult                     backdrop_path  \
#  0             0    NaN                               NaN
#  1     tt0199602    0.0  /fOnjxCbR3Poar7voHcaQrvYqQMH.jpg
#  2     tt0293429    0.0  /9yBVqNruk6Ykrwc32qrK2TIE5xw.jpg
#  3     tt0499097    0.0  /qV7HOOZvBLYnjQpSWIVl7mQiAjx.jpg
#  4     tt0870154    0.0  /7WJjFviFBffEJvkAms4uWwbcVUk.jpg
#  ...         ...    ...                               ...
#  3705  tt9895024    0.0   /S1kutYyoyuBJKGS0mXxv2fZNbr.jpg
#  3706  tt9896876    0.0  /hMvRbT6HOqERhh3K8kXbaLz9LlZ.jpg
#  3707  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
#  3708  tt9900940    0.0  /3jjWLg5bevWqReyVroYqxwVrH0k.jpg
#  3709  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
#
#                                    belongs_to_collection       budget  \
#  0                                                   NaN          NaN
#  1                                                   NaN          0.0
#  2     {'id': 931431, 'name': 'Mortal Kombat (Reboot)...   20000000.0
#  3                                                   NaN          0.0
#  4     {'id': 861429, 'name': 'Jungle Cruise Collecti...  200000000.0
#  ...                                                 ...          ...
#  3705                                                NaN          0.0
#  3706                                                NaN          0.0
#  3707                                                NaN          0.0
#  3708                                                NaN          0.0
#  3709                                                NaN          0.0
#
#                                                   genres  \
#  0                                                   NaN
#  1                        [{'id': 35, 'name': 'Comedy'}]
#  2     [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#  3     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#  4     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#  ...                                                 ...
#  3705  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#  3706  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#  3707                     [{'id': 27, 'name': 'Horror'}]
#  3708  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#  3709  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
#
#                                       homepage        id original_language  \
#  0                                         NaN       NaN               NaN
#  1                                         NaN  894346.0                en
#  2           https://www.mortalkombatmovie.net  460465.0                en
#  3        https://www.amazon.com/dp/B08VFD1Y3B  567189.0                en
#  4     https://movies.disney.com/jungle-cruise  451048.0                en
#  ...                                       ...       ...               ...
#  3705                                      NaN  834443.0                de
#  3706                                      NaN  821493.0                en
#  3707                                      NaN  870671.0                en
#  3708                                      NaN  861294.0                en
#  3709                                      NaN  630392.0                en
#
#                      original_title  ... runtime  \
#  0                              NaN  ...     NaN
#  1                   Holy Hollywood  ...    82.0
#  2                    Mortal Kombat  ...   110.0
#  3     Tom Clancy's Without Remorse  ...   109.0
#  4                    Jungle Cruise  ...   127.0
#  ...                            ...  ...     ...
#  3705                   Heikos Welt  ...   118.0
#  3706       India Sweets and Spices  ...   101.0
#  3707                   The Hunting  ...    91.0
#  3708                  The Scrapper  ...    87.0
#  3709                    The Cursed  ...   111.0
#
#                                         spoken_languages    status  \
#  0                                                   NaN       NaN
#  1                                                    []  Released
#  2     [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#  3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  4     [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
#  ...                                                 ...       ...
#  3705  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
#  3706  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3707  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3708  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#  3709  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                tagline                         title video  \
#  0                                 NaN                           NaN   NaN
#  1                                 NaN                Holy Hollywood   0.0
#  2                      Get over here.                 Mortal Kombat   0.0
#  3     From the author of Rainbow Six.  Tom Clancy's Without Remorse   0.0
#  4                                 NaN                 Jungle Cruise   0.0
#  ...                               ...                           ...   ...
#  3705                              NaN                 Heiko's World   0.0
#  3706            Let the aunties talk.       India Sweets and Spices   0.0
#  3707                Hunger runs deep.                   The Hunting   0.0
#  3708      You can't escape your past.                  The Scrapper   0.0
#  3709                              NaN                    The Cursed   0.0
#
#        vote_average  vote_count certification                      file
#  0              NaN         NaN           NaN  final_tmdb_data_2021.csv
#  1            0.000         0.0           NaN  final_tmdb_data_2021.csv
#  2            7.200      4887.0             R  final_tmdb_data_2021.csv
#  3            7.062      2017.0             R  final_tmdb_data_2021.csv
#  4            7.501      4621.0         PG-13  final_tmdb_data_2021.csv
#  ...            ...         ...           ...                       ...
#  3705         0.000         0.0           NaN  final_tmdb_data_2021.csv
#  3706         5.000         4.0         PG-13  final_tmdb_data_2021.csv
#  3707         4.893        28.0           NaN  final_tmdb_data_2021.csv
#  3708         6.000         2.0           NaN  final_tmdb_data_2021.csv
#  3709         6.764       109.0             R  final_tmdb_data_2021.csv
#
#  [3710 rows x 27 columns]]

# %%
df = pd.concat(dfs, ignore_index=True)
df.head(3)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0249516    0.0  /t7zb6CnRQwhzQSq0apR4ESFYiWN.jpg                   NaN
# 2  tt0285252    0.0  /pKOHinAVIkyqLliMaTHCSL1T4zU.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  65000000.0  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# 2   4000000.0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             homepage        id  \
# 0                                                NaN       NaN
# 1  http://www.thresholdanimationstudios.com/video...  116977.0
# 2                                                NaN  112074.0
#
#   original_language  original_title  ... runtime  \
# 0               NaN             NaN  ...     NaN
# 1                en      Foodfight!  ...    87.0
# 2                pl  Life's a Beach  ...   100.0
#
#                                     spoken_languages    status tagline  \
# 0                                                NaN       NaN     NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released     NaN
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released     NaN
#
#             title video  vote_average  vote_count certification  \
# 0             NaN   NaN           NaN         NaN           NaN
# 1      Foodfight!   0.0         1.856       108.0         PG-13
# 2  Life's a Beach   0.0         2.500         5.0             R
#
#                        file
# 0  final_tmdb_data_2012.csv
# 1  final_tmdb_data_2012.csv
# 2  final_tmdb_data_2012.csv
#
# [3 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39156 entries, 0 to 39155
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                39156 non-null  object
#  1   adult                  39146 non-null  float64
#  2   backdrop_path          26759 non-null  object
#  3   belongs_to_collection  2318 non-null   object
#  4   budget                 39146 non-null  float64
#  5   genres                 39146 non-null  object
#  6   homepage               10512 non-null  object
#  7   id                     39146 non-null  float64
#  8   original_language      39146 non-null  object
#  9   original_title         39146 non-null  object
#  10  overview               38353 non-null  object
#  11  popularity             39146 non-null  float64
#  12  poster_path            36751 non-null  object
#  13  production_companies   39146 non-null  object
#  14  production_countries   39146 non-null  object
#  15  release_date           38499 non-null  object
#  16  revenue                39146 non-null  float64
#  17  runtime                39146 non-null  float64
#  18  spoken_languages       39146 non-null  object
#  19  status                 39146 non-null  object
#  20  tagline                13963 non-null  object
#  21  title                  39146 non-null  object
#  22  video                  39146 non-null  float64
#  23  vote_average           39146 non-null  float64
#  24  vote_count             39146 non-null  float64
#  25  certification          8190 non-null   object
#  26  file                   39156 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 8.1+ MB

# %%
#adding files from 2012 to 2022
final_df = df[['imdb_id','budget', 'revenue', 'certification', 'runtime','genres']]
final_df.head()
# Out:
#      imdb_id      budget    revenue certification  runtime  \
# 0          0         NaN        NaN           NaN      NaN
# 1  tt0249516  65000000.0    73706.0         PG-13     87.0
# 2  tt0285252   4000000.0        0.0             R    100.0
# 3  tt0293069         0.0        0.0           NaN     86.0
# 4  tt0337692  25000000.0  8784318.0             R    137.0
#
#                                               genres
# 0                                                NaN
# 1  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# 2                     [{'id': 35, 'name': 'Comedy'}]
# 3                   [{'id': 53, 'name': 'Thriller'}]
# 4  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...

# %%
final_df.shape
# Out:
# (39156, 6)

# %%
final_df.to_csv('big_data/combined_years.csv.gz', compression="gzip", index=False)
